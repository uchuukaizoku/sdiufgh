# %% [markdown]
# <a href="https://colab.research.google.com/github/uchuukaizoku/sdiufgh/blob/main/Segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Install Requirements**

# %%
#@title Press play to install requirements for image segmentation
# !git clone https://github.com/jccc0/image-segmentation-keras.git
# %cd image-segmentation-keras/
# !python setup.py install
# Out:
# Cloning into 'image-segmentation-keras'...
# remote: Enumerating objects: 1173, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 1173 (delta 5), reused 0 (delta 0), pack-reused 1162
# Receiving objects: 100% (1173/1173), 3.29 MiB | 22.62 MiB/s, done.
# Resolving deltas: 100% (756/756), done.

# %% [markdown]
# # **Select Input and Output**

# %%
#@title Select Input and Output Image
input_Image = 'stptb.jpeg' #@param {type:"string"}
output_image = 'out.jpg' #@param {type:"string"}

# %%
#@title Run segmentation
import tensorflow as tf
from keras_segmentation.pretrained import pspnet_50_ADE_20K , pspnet_101_cityscapes, pspnet_101_voc12
model = pspnet_101_cityscapes() # load the pretrained model trained on Cityscapes dataset

out = model.predict_segmentation(
    inp="../" + input_Image,
    out_fname="../" + output_image
)

from IPython.display import Image
Image('../' + output_image)
